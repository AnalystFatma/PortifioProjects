# %%
#analyze
import pandas as pd
import seaborn as sns
import numpy as np

#visualize
import matplotlib
import matplotlib.pyplot as plt
plt.style.use('ggplot')
from matplotlib.pyplot import figure

#store plot in notebook
# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8)

#read
df = pd.read_csv(r'/Users/fatma/Desktop/excel/property.csv')

# %%
df.head()
# Out:
#         id     scrape_id last_scraped                                 name  \
# 0   241032  2.020000e+13   04/01/2016         Stylish Queen Anne Apartment
# 1   953595  2.020000e+13   04/01/2016   Bright & Airy Queen Anne Apartment
# 2  3308979  2.020000e+13   04/01/2016  New Modern House-Amazing water view
# 3  7421966  2.020000e+13   04/01/2016                   Queen Anne Chateau
# 4   278830  2.020000e+13   04/01/2016       Charming craftsman 3 bdm house
#
#   experiences_offered   host_id host_name  host_since host_city   host_state  \
# 0                none    956883     Maija  11/08/2011   Seattle   Washington
# 1                none   5177328    Andrea  21/02/2013   Seattle   Washington
# 2                none  16708587      Jill  12/06/2014   Seattle   Washington
# 3                none   9851441     Emily  06/11/2013   Seattle   Washington
# 4                none   1452570     Emily  29/11/2011   Seattle   Washington
#
# ...

# %%
#columns type
df.dtypes.head()
# Out:
# id                       int64
# scrape_id              float64
# last_scraped            object
# name                    object
# experiences_offered     object
# dtype: object

# %%
#convert type

df['price'] = df['price'].astype('Int64')

#df['zipcode'] = df['zipcode'].astype('Int64')

# %%
#sort
df = df.sort_values(by=['price'], inplace=False, ascending=True)

# %%
pd.set_option('display.max_rows', None)

# %%
df.head()
# Out:
#             id     scrape_id last_scraped  \
# 53    10310373  2.020000e+13   04/01/2016
# 3573  10248139  2.020000e+13   04/01/2016
# 1917   8566475  2.020000e+13   04/01/2016
# 2693  10012724  2.020000e+13   04/01/2016
# 2894   9727857  2.020000e+13   04/01/2016
#
#                                      name experiences_offered   host_id  \
# 53          Cozy, cute, Queen Anne living                none  53050379
# 3573  Pullout Bed in CAP HILL on Pike St.                none  28883039
# 1917  Between downtown & SeaTac, Bohemian                none  45084253
# 2693  Ideal Location + Bike - (Bttm Bunk)                none  50201633
# 2894   Ideal Location + Bike - (Top Bunk)                none  50201633
#
#        host_name  host_since host_city   host_state  ...         amenities12  \
# 53           Ana  02/01/2016   Seattle   Washington  ...  Family/Kid Hangers
# 3573  J. Ildrich  06/03/2015   Seattle   Washington  ...                 NaN
# ...

# %%
df1 = df.groupby('zipcode', sort=False)[['zipcode','price']].mean()
df1.head()
# Out:
#          zipcode       price
# zipcode
# 98119.0  98119.0  167.148936
# 98122.0  98122.0  132.337292
# 98108.0  98108.0      83.875
# 98117.0  98117.0  111.262195
# 98107.0  98107.0  130.238889

# %%
#bar chart price and zipcode
x = df1['price']
y = df1['zipcode'].astype('bytes')
fig = plt.figure(figsize = (35, 15))
plt.bar(x, y, edgecolor='black',color='red', width=5)

plt.title("price vs Gross zipcode",  fontsize=30)

plt.xlabel('price' ,fontsize=30)
plt.ylabel('zipcode',  fontsize=30)


plt.show()
